# %% [markdown]
# <a href="https://colab.research.google.com/github/kristabhell12/mojixbootcamp_v2/blob/main/Copia_de_TEMPLATE_Bootcamp2_0_ipynb_Giovannka_Oliver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandasql

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Exercise 1
# Using pandas
# Retrieve from df dataframe the number of cases and deaths in South America Countries.  (Hint: Use groupby by continent and location)

# %%
import pandas as pd

df = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")
df.head()
df.groupby(['continent','location']).sum('South America')[['new_cases','new_deaths']]
#df.groupby(['class_life_expectancy'],sum()[["new_deaths"]])
# Out:
#                             new_cases  new_deaths
# continent     location
# Africa        Algeria        269556.0      6878.0
#               Angola         102636.0      1920.0
#               Benin           27525.0       163.0
#               Botswana       325850.0      2777.0
#               Burkina Faso    21128.0       387.0
# ...                               ...         ...
# South America Paraguay       712907.0     19357.0
#               Peru          4057917.0    215945.0
#               Suriname        81007.0      1382.0
#               Uruguay        975285.0      7429.0
#               Venezuela      540796.0      5787.0
#
# [231 rows x 2 columns]

# %%
# Add your solution here
# df[df[]].groupby()....

# %% [markdown]
# ## Exercise 2
# Using pandas
#
# 1.  Create a new column called "class_life_expectancy" and classify life_expectancy column in 5 values:
#   - 1_less_than_55
#   - 2_between_55_and_64
#   - 3_between_65_and_74
#   - 4_equal_greater_than_75
#   - 5_other
# 2.  Get the sum of new_deaths grouped by class_life_expectancy

# %%
#df = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")
#df.head()
#df['class_life_expectancy']= '5_other'
df.loc[df['life_expectancy']<55, 'class_life_expectancy'] = '1_less_than_55'
df.loc[(df['life_expectancy']>=55) & (df['life_expectancy']<=64), 'class_life_expectancy'] = '2_between_55_and_64'
df.loc[(df['life_expectancy']>=65) & (df['life_expectancy']<=74), 'class_life_expectancy'] = '3_between_65_and_74'
df.loc[df['life_expectancy']>=75, 'class_life_expectancy'] = '4_equal_greater_than_75'
df.sample(10)
#df.head()
#df[['life_expectancy']]
#df[]
# Out:
#        iso_code      continent           location        date  total_cases  \
# 50842       DJI         Africa           Djibouti  2020-05-28       2914.0
# 161802      WSM        Oceania              Samoa  2021-03-03          3.0
# 62574       FRO         Europe     Faeroe Islands  2020-05-29        187.0
# 56842       GNQ         Africa  Equatorial Guinea  2022-02-18      15870.0
# 15589       BGD           Asia         Bangladesh  2020-08-08     255113.0
# 29343       BGR         Europe           Bulgaria  2021-09-12     471272.0
# 124808      MCO         Europe             Monaco  2022-07-01      13047.0
# 4199        AND         Europe            Andorra  2021-09-15      15108.0
# 76960       GTM  North America          Guatemala  2020-06-09       7866.0
# 55358       SLV  North America        El Salvador  2020-07-01       6736.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 50842       217.0             123.857          20.0         2.0
# 161802        0.0               0.000           NaN         NaN
# 62574         0.0               0.000           NaN         NaN
# 56842         0.0               2.429         182.0         0.0
# 15589      2611.0            2179.000        3365.0        32.0
# 29343       437.0            1319.857       19522.0        53.0
# 124808       41.0              39.714          58.0         0.0
# 4199          9.0               5.429         130.0         0.0
# 76960       364.0             325.714         289.0        22.0
# 55358       298.0             226.571         182.0         8.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 50842                 1.429  ...          24.5                     NaN
# 161802                  NaN  ...          38.1                     NaN
# 62574                   NaN  ...           NaN                     NaN
# 56842                 0.000  ...           NaN                  24.640
# 15589                33.286  ...          44.7                  34.808
# 29343                58.143  ...          44.4                     NaN
# 124808                0.143  ...           NaN                     NaN
# 4199                  0.000  ...          37.8                     NaN
# 76960                23.714  ...           NaN                  76.665
# 55358                 9.000  ...          18.8                  90.650
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 50842                        1.400            67.11                    0.524
# 161802                         NaN            73.32                    0.715
# 62574                          NaN            80.67                      NaN
# 56842                        2.100            58.74                    0.592
# 15589                        0.800            72.59                    0.632
# 29343                        7.454            75.05                    0.816
# 124808                      13.800            86.75                      NaN
# 4199                           NaN            83.73                    0.868
# 76960                        0.600            74.30                    0.663
# 55358                        1.300            73.32                    0.673
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 50842                                    NaN                          NaN
# 161802                                   NaN                          NaN
# 62574                                    NaN                          NaN
# 56842                                    NaN                          NaN
# 15589                                    NaN                          NaN
# 29343                                35277.7                        19.13
# 124808                                   NaN                          NaN
# 4199                                     NaN                          NaN
# 76960                                    NaN                          NaN
# 55358                                    NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million  \
# 50842                NaN                                      NaN
# 161802               NaN                                      NaN
# 62574                NaN                                      NaN
# 56842                NaN                                      NaN
# 15589                NaN                                      NaN
# 29343               48.7                              5123.203059
# 124808               NaN                                      NaN
# 4199                 NaN                                      NaN
# 76960                NaN                                      NaN
# 55358                NaN                                      NaN
#
#           class_life_expectancy
# 50842       3_between_65_and_74
# 161802      3_between_65_and_74
# 62574   4_equal_greater_than_75
# 56842       2_between_55_and_64
# 15589       3_between_65_and_74
# 29343   4_equal_greater_than_75
# 124808  4_equal_greater_than_75
# 4199    4_equal_greater_than_75
# 76960                   5_other
# 55358       3_between_65_and_74
#
# [10 rows x 68 columns]

# %%
df.groupby('class_life_expectancy').sum()[['new_deaths']]
# Out:
#                          new_deaths
# class_life_expectancy
# 1_less_than_55               4288.0
# 2_between_55_and_64         32557.0
# 3_between_65_and_74       7927383.0
# 4_equal_greater_than_75   4653527.0
# 5_other                  14139572.0

# %% [markdown]
# ## Exercise 3 (Inventory Discrepancy)
#
#
# - Remove dups
# - Aggregate
# - Merge 2 datasets

# %%
df_expected = pd.read_csv("https://storage.googleapis.com/mojix-devops-wildfire-bucket/analytics/bootcamp_2_0/Bootcamp_DataAnalysis_Expected.csv", encoding="latin-1", dtype=str)

# %%
df_counted = pd.read_csv("https://storage.googleapis.com/mojix-devops-wildfire-bucket/analytics/bootcamp_2_0/Bootcamp_DataAnalysis_Counted.csv", encoding="latin-1", dtype=str)

# %%
df_expected.head()
# Out:
#   Retail_Clearance Retail_InTransitQTY Retail_Product_Color  \
# 0            false                   0               BRANCO
# 1            false                   0                 ROSA
# 2            false                   0                  NaN
# 3            false                   0                JEANS
# 4            false                   0                JEANS
#
#   Retail_Product_Dimension Retail_Product_ExternalSKU Retail_Product_ImageURL  \
# 0                    NaVal                      NaVal                   NaVal
# 1                    NaVal                      NaVal                   NaVal
# 2                    NaVal                      NaVal                   NaVal
# 3                    NaVal                      NaVal                   NaVal
# 4                    NaVal                      NaVal                   NaVal
#
#   Retail_Product_Level1 Retail_Product_Level1Name Retail_Product_Level2  \
# 0                     C                 VESTUARIO                 NaVal
# 1                     C                 VESTUARIO                 NaVal
# 2                     H        ELETRO-ELETRONICOS                 NaVal
# 3                     C                 VESTUARIO                 NaVal
# 4                     C                 VESTUARIO                 NaVal
#
#   Retail_Product_Level2Name  ... Retail_SFMax Retail_SFMin  \
# 0                        CR  ...            0            0
# 1                        CY  ...            0            0
# 2                        HZ  ...            0            0
# 3                        CY  ...            0            0
# 4                        CY  ...            0            0
#
#             Retail_SOHDate Retail_SOHQTY Retail_SOHQTY_SF Retail_SOHQTY_SR  \
# 0  2022-08-16 07:00:36.468             1                1                0
# 1  2022-08-16 07:00:36.468             3                3                0
# 2  2022-08-16 07:00:36.468             1                1                0
# 3  2022-08-16 07:00:36.468             3                3                0
# 4  2022-08-16 07:00:36.468             2                2                0
#
#   Retail_StoreInProcess Retail_StoreNumber            serial thingTypeId
# 0                     0                233  233_009568860004         384
# 1                     0                233  233_009384260002         384
# 2                     0                233  233_009735510000         384
# 3                     0                233  233_009579550002         384
# 4                     0                233  233_009633210004         384
#
# [5 rows x 35 columns]

# %%
df_counted.head()
# Out:
#                        RFID    Retail_CycleCountDate Retail_CycleCountDate_ts  \
# 0  E00000000000000000113053  2022-08-16 11:16:06.159            1660648566159
# 1  303405369430D444A817D9A4  2022-08-16 11:16:06.159            1660648566159
# 2  303405B31009C484A817D9FC  2022-08-16 11:16:06.159            1660648566159
# 3  3034055DD0271040EE7A6CC2  2022-08-16 11:16:06.159            1660648566159
# 4  303405C5CC57E4428FA6AE49  2022-08-16 11:16:06.159            1660648566159
#
#     Retail_Disposition Retail_Product_Color Retail_Product_ImageURL  \
# 0  SELLABLE_ACCESSIBLE                  NaN                     NaN
# 1  SELLABLE_ACCESSIBLE                  NaN                     NaN
# 2  SELLABLE_ACCESSIBLE                  NaN                     NaN
# 3  SELLABLE_ACCESSIBLE                  NaN                     NaN
# 4  SELLABLE_ACCESSIBLE                  NaN                     NaN
#
#   Retail_Product_Level1 Retail_Product_Level1Name Retail_Product_Level2  \
# 0                   NaN                       NaN                   NaN
# 1                     H        ELETRO-ELETRONICOS                   NaN
# 2                     H        ELETRO-ELETRONICOS                   NaN
# 3                     H        ELETRO-ELETRONICOS                   NaN
# 4                     B               LAR- TEXTIL                   NaN
#
#   Retail_Product_Level2Name  ... Retail_ZoneName Retail_ZoneType shardId  \
# 0                       NaN  ...  233_SALESFLOOR      SALESFLOOR      23
# 1                        HD  ...  233_SALESFLOOR      SALESFLOOR      23
# 2                        HB  ...  233_SALESFLOOR      SALESFLOOR      23
# 3                        HJ  ...  233_SALESFLOOR      SALESFLOOR      23
# 4                        BN  ...  233_SALESFLOOR      SALESFLOOR      23
#
#   viz_groupCode viz_groupId                    viz_id  \
# 0           NaN          23   23.356.9025563068704443
# 1           NaN          23  23.356.13836371861512146
# 2           NaN          23  23.356.13871892345401185
# 3           NaN          23  23.356.13987320026117128
# 4           NaN          23  23.356.13595963301105791
#
#            viz_serialNumber viz_source viz_thingTypeCode  \
# 0  E00000000000000000113053     MOBILE              ITEM
# 1  303405369430D444A817D9A4     MOBILE              ITEM
# 2  303405B31009C484A817D9FC     MOBILE              ITEM
# 3  3034055DD0271040EE7A6CC2     MOBILE              ITEM
# 4  303405C5CC57E4428FA6AE49     MOBILE              ITEM
#
#                   viz_time
# 0  2022-08-16 11:16:06.159
# 1  2022-08-16 11:16:06.159
# 2  2022-08-16 11:16:06.159
# 3  2022-08-16 11:16:06.159
# 4  2022-08-16 11:16:06.159
#
# [5 rows x 29 columns]

# %%
df_expected.sample(2).T
# Out:
#                                                 2328  \
# Retail_Clearance                               false
# Retail_InTransitQTY                                0
# Retail_Product_Color                             NaN
# Retail_Product_Dimension                       NaVal
# Retail_Product_ExternalSKU                     NaVal
# Retail_Product_ImageURL                        NaVal
# Retail_Product_Level1                              H
# Retail_Product_Level1Name         ELETRO-ELETRONICOS
# Retail_Product_Level2                          NaVal
# Retail_Product_Level2Name                         HB
# Retail_Product_Level3                            HBH
# Retail_Product_Level3Name                        HBH
# Retail_Product_Level4                          HBHAC
# Retail_Product_Level4Name                       HBHA
# Retail_Product_Level5                  MOTO G31 AZUL
# Retail_Product_Level5Name                      HBHAA
# Retail_Product_Manufacturer                    NaVal
# Retail_Product_Name              MOTO G31 128GB AZUL
# Retail_Product_RFIDTagged                      NaVal
# Retail_Product_SKU                        9389690000
# Retail_Product_Size                              NaN
# Retail_Product_Style                        MOTOROLA
# Retail_Product_UOM                             NaVal
# Retail_Product_UPC                    00093896900011
# Retail_Product_UPCs                   00093896900011
# Retail_SFMax                                       0
# Retail_SFMin                                       0
# Retail_SOHDate               2022-08-16 07:00:36.468
# Retail_SOHQTY                                      2
# Retail_SOHQTY_SF                                   2
# Retail_SOHQTY_SR                                   0
# Retail_StoreInProcess                              0
# Retail_StoreNumber                               233
# serial                              233_009389690000
# thingTypeId                                      384
#
#                                                                  2273
# Retail_Clearance                                                false
# Retail_InTransitQTY                                                 0
# Retail_Product_Color                                            JEANS
# Retail_Product_Dimension                                        NaVal
# Retail_Product_ExternalSKU                                      NaVal
# Retail_Product_ImageURL                                         NaVal
# Retail_Product_Level1                                               C
# Retail_Product_Level1Name                                   VESTUARIO
# Retail_Product_Level2                                           NaVal
# Retail_Product_Level2Name                                          CY
# Retail_Product_Level3                                             CYC
# Retail_Product_Level3Name                                         CYC
# Retail_Product_Level4                                           CYCBB
# Retail_Product_Level4Name                                        CYCB
# Retail_Product_Level5                                           JEANS
# Retail_Product_Level5Name                                       CYCBB
# Retail_Product_Manufacturer                                     NaVal
# Retail_Product_Name          CALCA JEANS PS PRD INK USED TANK BARRA D
# Retail_Product_RFIDTagged                                       NaVal
# Retail_Product_SKU                                         9481090001
# Retail_Product_Size                                                46
# Retail_Product_Style                                 CALÇA JEANS PLUS
# Retail_Product_UOM                                              NaVal
# Retail_Product_UPC                                     00094810900148
# Retail_Product_UPCs                                    00094810900148
# Retail_SFMax                                                        0
# Retail_SFMin                                                        0
# Retail_SOHDate                                2022-08-16 07:00:36.468
# Retail_SOHQTY                                                       1
# Retail_SOHQTY_SF                                                    1
# Retail_SOHQTY_SR                                                    0
# Retail_StoreInProcess                                               0
# Retail_StoreNumber                                                233
# serial                                               233_009481090001
# thingTypeId                                                       384

# %%
df_expected.shape
# Out:
# (3187, 35)

# %%
df_expected['Retail_Product_SKU'].nunique()
# Out:
# 3187

# %%
df_counted.sample(2).T
# Out:
#                                                        6676  \
# RFID                               30340505A41D51428FA6B80E
# Retail_CycleCountDate               2022-08-16 12:38:46.852
# Retail_CycleCountDate_ts                      1660653526852
# Retail_Disposition                      SELLABLE_ACCESSIBLE
# Retail_Product_Color                                  PRETO
# Retail_Product_ImageURL                                 NaN
# Retail_Product_Level1                                     C
# Retail_Product_Level1Name                         VESTUARIO
# Retail_Product_Level2                                   NaN
# Retail_Product_Level2Name                                C2
# Retail_Product_Level3                                   C2A
# Retail_Product_Level3Name                               C2A
# Retail_Product_Name        CORSARIO BAS PA PTO W C2 M PRETO
# Retail_Product_SKU                               8228130002
# Retail_Product_Size                                       M
# Retail_Product_Style                                  CALÇA
# Retail_Product_UOM                                      NaN
# Retail_Product_UPC                           00082281300215
# Retail_StoreNumber                                      233
# Retail_ZoneName                              233_SALESFLOOR
# Retail_ZoneType                                  SALESFLOOR
# shardId                                                  23
# viz_groupCode                                           NaN
# viz_groupId                                              23
# viz_id                             23.356.13379469938819443
# viz_serialNumber                   30340505A41D51428FA6B80E
# viz_source                                           MOBILE
# viz_thingTypeCode                                      ITEM
# viz_time                            2022-08-16 12:38:46.852
#
#                                                                1962
# RFID                                       303405E57057EA428FA6AE41
# Retail_CycleCountDate                       2022-08-16 12:31:32.768
# Retail_CycleCountDate_ts                              1660653092768
# Retail_Disposition                              SELLABLE_ACCESSIBLE
# Retail_Product_Color                                           ROSA
# Retail_Product_ImageURL                                         NaN
# Retail_Product_Level1                                             C
# Retail_Product_Level1Name                                 VESTUARIO
# Retail_Product_Level2                                           NaN
# Retail_Product_Level2Name                                        CS
# Retail_Product_Level3                                           CSA
# Retail_Product_Level3Name                                       CSA
# Retail_Product_Name        BLUSA SEM MANGA CS PRD coordenado 2 VIVA
# Retail_Product_SKU                                       9660490002
# Retail_Product_Size                                               P
# Retail_Product_Style                                    BLUSA MALHA
# Retail_Product_UOM                                              NaN
# Retail_Product_UPC                                   00096604900259
# Retail_StoreNumber                                              233
# Retail_ZoneName                                      233_SALESFLOOR
# Retail_ZoneType                                          SALESFLOOR
# shardId                                                          23
# viz_groupCode                                                   NaN
# viz_groupId                                                      23
# viz_id                                     23.356.14234499147120227
# viz_serialNumber                           303405E57057EA428FA6AE41
# viz_source                                                   MOBILE
# viz_thingTypeCode                                              ITEM
# viz_time                                    2022-08-16 12:31:32.768

# %%
df_counted.shape
# Out:
# (7924, 29)

# %%
df_counted['RFID'].nunique()
# Out:
# 7712

# %%
df_counted = df_counted.drop_duplicates('RFID')

# %%
df_B = df_counted.groupby('Retail_Product_SKU').count()[['RFID']].reset_index()

# %%
df_B.head()
# Out:
#   Retail_Product_SKU  RFID
# 0         3555270034     1
# 1         3555270035     2
# 2         3555270036     2
# 3         3741470002     1
# 4         3741470003     3

# %%
df_expected.head()
# Out:
#   Retail_Clearance Retail_InTransitQTY Retail_Product_Color  \
# 0            false                   0               BRANCO
# 1            false                   0                 ROSA
# 2            false                   0                  NaN
# 3            false                   0                JEANS
# 4            false                   0                JEANS
#
#   Retail_Product_Dimension Retail_Product_ExternalSKU Retail_Product_ImageURL  \
# 0                    NaVal                      NaVal                   NaVal
# 1                    NaVal                      NaVal                   NaVal
# 2                    NaVal                      NaVal                   NaVal
# 3                    NaVal                      NaVal                   NaVal
# 4                    NaVal                      NaVal                   NaVal
#
#   Retail_Product_Level1 Retail_Product_Level1Name Retail_Product_Level2  \
# 0                     C                 VESTUARIO                 NaVal
# 1                     C                 VESTUARIO                 NaVal
# 2                     H        ELETRO-ELETRONICOS                 NaVal
# 3                     C                 VESTUARIO                 NaVal
# 4                     C                 VESTUARIO                 NaVal
#
#   Retail_Product_Level2Name  ... Retail_SFMax Retail_SFMin  \
# 0                        CR  ...            0            0
# 1                        CY  ...            0            0
# 2                        HZ  ...            0            0
# 3                        CY  ...            0            0
# 4                        CY  ...            0            0
#
#             Retail_SOHDate Retail_SOHQTY Retail_SOHQTY_SF Retail_SOHQTY_SR  \
# 0  2022-08-16 07:00:36.468             1                1                0
# 1  2022-08-16 07:00:36.468             3                3                0
# 2  2022-08-16 07:00:36.468             1                1                0
# 3  2022-08-16 07:00:36.468             3                3                0
# 4  2022-08-16 07:00:36.468             2                2                0
#
#   Retail_StoreInProcess Retail_StoreNumber            serial thingTypeId
# 0                     0                233  233_009568860004         384
# 1                     0                233  233_009384260002         384
# 2                     0                233  233_009735510000         384
# 3                     0                233  233_009579550002         384
# 4                     0                233  233_009633210004         384
#
# [5 rows x 35 columns]

# %%
df_B = df_counted.groupby('Retail_Product_SKU').count()[['RFID']].reset_index().rename(columns={'RFID':'Retail_CCQTY'})

# %%
df_B.sample(10)
# Out:
#      Retail_Product_SKU  Retail_CCQTY
# 96           7744280001             3
# 1676         9470230002             1
# 1639         9465200000             2
# 469          9170490000             1
# 3682         9687100004             1
# 1037         9395940008             1
# 278          8688010000             2
# 2368         9543620003             1
# 131          8218660003             3
# 305          8806210003             3

# %%
df_expected.head().T
my_cols_selected=['Retail_Product_Color',
'Retail_Product_Level1',
'Retail_Product_Level1Name',
'Retail_Product_Level2Name',
'Retail_Product_Level3Name',
'Retail_Product_Level4Name',
'Retail_Product_Name',
'Retail_Product_SKU',
'Retail_Product_Size',
'Retail_Product_Style',
'Retail_SOHQTY']

# %%
df_A = df_expected[my_cols_selected]

# %%
df_A.head().T
# Out:
#                                                                   0  \
# Retail_Product_Color                                         BRANCO
# Retail_Product_Level1                                             C
# Retail_Product_Level1Name                                 VESTUARIO
# Retail_Product_Level2Name                                        CR
# Retail_Product_Level3Name                                       CRB
# Retail_Product_Level4Name                                      CRBK
# Retail_Product_Name        CALCINHA CR SLO ELLA ESTAMPADO CINZA P B
# Retail_Product_SKU                                       9568860004
# Retail_Product_Size                                               P
# Retail_Product_Style                                   KIT CALCINHA
# Retail_SOHQTY                                                     1
#
#                                                                   1  \
# Retail_Product_Color                                           ROSA
# Retail_Product_Level1                                             C
# Retail_Product_Level1Name                                 VESTUARIO
# Retail_Product_Level2Name                                        CY
# Retail_Product_Level3Name                                       CYA
# Retail_Product_Level4Name                                      CYAE
# Retail_Product_Name        BERMUDA SARJA CRN SLO INK ABERTURA BARRA
# Retail_Product_SKU                                       9384260002
# Retail_Product_Size                                              40
# Retail_Product_Style                             BOTTOM CURTO SARJA
# Retail_SOHQTY                                                     3
#
#                                                                   2  \
# Retail_Product_Color                                            NaN
# Retail_Product_Level1                                             H
# Retail_Product_Level1Name                        ELETRO-ELETRONICOS
# Retail_Product_Level2Name                                        HZ
# Retail_Product_Level3Name                                       HZB
# Retail_Product_Level4Name                                      HZBO
# Retail_Product_Name        RELOGIO FEM MONDAINE PRATA KIT COLAR ANA
# Retail_Product_SKU                                       9735510000
# Retail_Product_Size                                             NaN
# Retail_Product_Style                             KIT FEMININO PRATA
# Retail_SOHQTY                                                     1
#
#                                                                   3  \
# Retail_Product_Color                                          JEANS
# Retail_Product_Level1                                             C
# Retail_Product_Level1Name                                 VESTUARIO
# Retail_Product_Level2Name                                        CY
# Retail_Product_Level3Name                                       CYA
# Retail_Product_Level4Name                                      CYAA
# Retail_Product_Name        CALCA JEANS CF MSA INK USED TANK DIRT LI
# Retail_Product_SKU                                       9579550002
# Retail_Product_Size                                              38
# Retail_Product_Style                                    CALÇA JEANS
# Retail_SOHQTY                                                     3
#
#                                                                   4
# Retail_Product_Color                                          JEANS
# Retail_Product_Level1                                             C
# Retail_Product_Level1Name                                 VESTUARIO
# Retail_Product_Level2Name                                        CY
# Retail_Product_Level3Name                                       CYC
# Retail_Product_Level4Name                                      CYCD
# Retail_Product_Name        SHORT JEANS PS PRD BARRA DOBRADA E PREGA
# Retail_Product_SKU                                       9633210004
# Retail_Product_Size                                              52
# Retail_Product_Style                        BOTTOM CURTO JEANS PLUS
# Retail_SOHQTY                                                     2

# %%
df_discrepancy = pd.merge(df_A, df_B, how='outer',left_on='Retail_Product_SKU', right_on='Retail_Product_SKU',indicator= True)

# %%
df_discrepancy.head()
# Out:
#   Retail_Product_Color Retail_Product_Level1 Retail_Product_Level1Name  \
# 0               BRANCO                     C                 VESTUARIO
# 1                 ROSA                     C                 VESTUARIO
# 2                  NaN                     H        ELETRO-ELETRONICOS
# 3                JEANS                     C                 VESTUARIO
# 4                JEANS                     C                 VESTUARIO
#
#   Retail_Product_Level2Name Retail_Product_Level3Name  \
# 0                        CR                       CRB
# 1                        CY                       CYA
# 2                        HZ                       HZB
# 3                        CY                       CYA
# 4                        CY                       CYC
#
#   Retail_Product_Level4Name                       Retail_Product_Name  \
# 0                      CRBK  CALCINHA CR SLO ELLA ESTAMPADO CINZA P B
# 1                      CYAE  BERMUDA SARJA CRN SLO INK ABERTURA BARRA
# 2                      HZBO  RELOGIO FEM MONDAINE PRATA KIT COLAR ANA
# 3                      CYAA  CALCA JEANS CF MSA INK USED TANK DIRT LI
# 4                      CYCD  SHORT JEANS PS PRD BARRA DOBRADA E PREGA
#
#   Retail_Product_SKU Retail_Product_Size     Retail_Product_Style  \
# 0         9568860004                   P             KIT CALCINHA
# 1         9384260002                  40       BOTTOM CURTO SARJA
# 2         9735510000                 NaN       KIT FEMININO PRATA
# 3         9579550002                  38              CALÇA JEANS
# 4         9633210004                  52  BOTTOM CURTO JEANS PLUS
#
#   Retail_SOHQTY  Retail_CCQTY     _merge
# 0             1           1.0       both
# 1             3           1.0       both
# 2             1           1.0       both
# 3             3           3.0       both
# 4             2           NaN  left_only

# %%
df_discrepancy.head()
# Out:
#   Retail_Product_Color Retail_Product_Level1 Retail_Product_Level1Name  \
# 0               BRANCO                     C                 VESTUARIO
# 1                 ROSA                     C                 VESTUARIO
# 2                  NaN                     H        ELETRO-ELETRONICOS
# 3                JEANS                     C                 VESTUARIO
# 4                JEANS                     C                 VESTUARIO
#
#   Retail_Product_Level2Name Retail_Product_Level3Name  \
# 0                        CR                       CRB
# 1                        CY                       CYA
# 2                        HZ                       HZB
# 3                        CY                       CYA
# 4                        CY                       CYC
#
#   Retail_Product_Level4Name                       Retail_Product_Name  \
# 0                      CRBK  CALCINHA CR SLO ELLA ESTAMPADO CINZA P B
# 1                      CYAE  BERMUDA SARJA CRN SLO INK ABERTURA BARRA
# 2                      HZBO  RELOGIO FEM MONDAINE PRATA KIT COLAR ANA
# 3                      CYAA  CALCA JEANS CF MSA INK USED TANK DIRT LI
# 4                      CYCD  SHORT JEANS PS PRD BARRA DOBRADA E PREGA
#
#   Retail_Product_SKU Retail_Product_Size     Retail_Product_Style  \
# 0         9568860004                   P             KIT CALCINHA
# 1         9384260002                  40       BOTTOM CURTO SARJA
# 2         9735510000                 NaN       KIT FEMININO PRATA
# 3         9579550002                  38              CALÇA JEANS
# 4         9633210004                  52  BOTTOM CURTO JEANS PLUS
#
#   Retail_SOHQTY  Retail_CCQTY     _merge
# 0             1           1.0       both
# 1             3           1.0       both
# 2             1           1.0       both
# 3             3           3.0       both
# 4             2           0.0  left_only

# %%
df_discrepancy['Retail_CCQTY']=df_discrepancy['Retail_CCQTY'].fillna(0)

# %%
df_discrepancy['Retail_CCQTY']=df_discrepancy['Retail_CCQTY'].astype(int)

# %%
df_discrepancy.head()
# Out:
#   Retail_Product_Color Retail_Product_Level1 Retail_Product_Level1Name  \
# 0               BRANCO                     C                 VESTUARIO
# 1                 ROSA                     C                 VESTUARIO
# 2                  NaN                     H        ELETRO-ELETRONICOS
# 3                JEANS                     C                 VESTUARIO
# 4                JEANS                     C                 VESTUARIO
#
#   Retail_Product_Level2Name Retail_Product_Level3Name  \
# 0                        CR                       CRB
# 1                        CY                       CYA
# 2                        HZ                       HZB
# 3                        CY                       CYA
# 4                        CY                       CYC
#
#   Retail_Product_Level4Name                       Retail_Product_Name  \
# 0                      CRBK  CALCINHA CR SLO ELLA ESTAMPADO CINZA P B
# 1                      CYAE  BERMUDA SARJA CRN SLO INK ABERTURA BARRA
# 2                      HZBO  RELOGIO FEM MONDAINE PRATA KIT COLAR ANA
# 3                      CYAA  CALCA JEANS CF MSA INK USED TANK DIRT LI
# 4                      CYCD  SHORT JEANS PS PRD BARRA DOBRADA E PREGA
#
#   Retail_Product_SKU Retail_Product_Size     Retail_Product_Style  \
# 0         9568860004                   P             KIT CALCINHA
# 1         9384260002                  40       BOTTOM CURTO SARJA
# 2         9735510000                 NaN       KIT FEMININO PRATA
# 3         9579550002                  38              CALÇA JEANS
# 4         9633210004                  52  BOTTOM CURTO JEANS PLUS
#
#   Retail_SOHQTY  Retail_CCQTY     _merge
# 0             1             1       both
# 1             3             1       both
# 2             1             1       both
# 3             3             3       both
# 4             2             0  left_only

# %%
df_discrepancy['Diff']=df_discrepancy['Retail_CCQTY']-df_discrepancy['Retail_SOHQTY']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-68dbcf1e3273> in <module>
# ----> 1 df_discrepancy['Diff']=df_discrepancy['Retail_CCQTY']-df_discrepancy['Retail_SOHQTY']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __sub__(self, other)
#      98     @unpack_zerodim_and_defer("__sub__")
#      99     def __sub__(self, other):
# --> 100         return self._arith_method(other, operator.sub)
#     101
#     102     @unpack_zerodim_and_defer("__rsub__")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _arith_method(self, other, op)
#    5524
#    5525         with np.errstate(all="ignore"):
# -> 5526             result = ops.arithmetic_op(lvalues, rvalues, op)
#    5527
#    5528         return self._construct_result(result, name=res_name)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     222         _bool_arith_check(op, left, right)
#     223
# --> 224         res_values = _na_arithmetic_op(left, right, op)
#     225
#     226     return res_values
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     171             # Don't do this for comparisons, as that will handle complex numbers
#     172             #  incorrectly, see GH#32047
# --> 173             result = _masked_arith_op(left, right, op)
#     174         else:
#     175             raise
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in _masked_arith_op(x, y, op)
#     110         # See GH#5284, GH#5035, GH#19448 for historical reference
#     111         if mask.any():
# --> 112             result[mask] = op(xrav[mask], yrav[mask])
#     113
#     114     else:
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
df_discrepancy['Retail_SOHQTY']=df_discrepancy['Retail_SOHQTY'].fillna(0).astype(int)

# %%
df_discrepancy['Diff']=df_discrepancy['Retail_CCQTY']-df_discrepancy['Retail_SOHQTY']

# %%
df_discrepancy.head()
# Out:
#   Retail_Product_Color Retail_Product_Level1 Retail_Product_Level1Name  \
# 0               BRANCO                     C                 VESTUARIO
# 1                 ROSA                     C                 VESTUARIO
# 2                  NaN                     H        ELETRO-ELETRONICOS
# 3                JEANS                     C                 VESTUARIO
# 4                JEANS                     C                 VESTUARIO
#
#   Retail_Product_Level2Name Retail_Product_Level3Name  \
# 0                        CR                       CRB
# 1                        CY                       CYA
# 2                        HZ                       HZB
# 3                        CY                       CYA
# 4                        CY                       CYC
#
#   Retail_Product_Level4Name                       Retail_Product_Name  \
# 0                      CRBK  CALCINHA CR SLO ELLA ESTAMPADO CINZA P B
# 1                      CYAE  BERMUDA SARJA CRN SLO INK ABERTURA BARRA
# 2                      HZBO  RELOGIO FEM MONDAINE PRATA KIT COLAR ANA
# 3                      CYAA  CALCA JEANS CF MSA INK USED TANK DIRT LI
# 4                      CYCD  SHORT JEANS PS PRD BARRA DOBRADA E PREGA
#
#   Retail_Product_SKU Retail_Product_Size     Retail_Product_Style  \
# 0         9568860004                   P             KIT CALCINHA
# 1         9384260002                  40       BOTTOM CURTO SARJA
# 2         9735510000                 NaN       KIT FEMININO PRATA
# 3         9579550002                  38              CALÇA JEANS
# 4         9633210004                  52  BOTTOM CURTO JEANS PLUS
#
#    Retail_SOHQTY  Retail_CCQTY     _merge  Diff
# 0              1             1       both     0
# 1              3             1       both    -2
# 2              1             1       both     0
# 3              3             3       both     0
# 4              2             0  left_only    -2

# %%
df_discrepancy['Unders']=df_discrepancy['Unders'].fillna(0).astype(int)

# %%
df_discrepancy.loc[df_discrepancy['Diff']<0, 'Unders']=df_discrepancy['Diff']*(-1)

# %%
df_discrepancy.head()
# Out:
#   Retail_Product_Color Retail_Product_Level1 Retail_Product_Level1Name  \
# 0               BRANCO                     C                 VESTUARIO
# 1                 ROSA                     C                 VESTUARIO
# 2                  NaN                     H        ELETRO-ELETRONICOS
# 3                JEANS                     C                 VESTUARIO
# 4                JEANS                     C                 VESTUARIO
#
#   Retail_Product_Level2Name Retail_Product_Level3Name  \
# 0                        CR                       CRB
# 1                        CY                       CYA
# 2                        HZ                       HZB
# 3                        CY                       CYA
# 4                        CY                       CYC
#
#   Retail_Product_Level4Name                       Retail_Product_Name  \
# 0                      CRBK  CALCINHA CR SLO ELLA ESTAMPADO CINZA P B
# 1                      CYAE  BERMUDA SARJA CRN SLO INK ABERTURA BARRA
# 2                      HZBO  RELOGIO FEM MONDAINE PRATA KIT COLAR ANA
# 3                      CYAA  CALCA JEANS CF MSA INK USED TANK DIRT LI
# 4                      CYCD  SHORT JEANS PS PRD BARRA DOBRADA E PREGA
#
#   Retail_Product_SKU Retail_Product_Size     Retail_Product_Style  \
# 0         9568860004                   P             KIT CALCINHA
# 1         9384260002                  40       BOTTOM CURTO SARJA
# 2         9735510000                 NaN       KIT FEMININO PRATA
# 3         9579550002                  38              CALÇA JEANS
# 4         9633210004                  52  BOTTOM CURTO JEANS PLUS
#
#    Retail_SOHQTY  Retail_CCQTY     _merge  Diff  Unders
# 0              1             1       both     0     NaN
# 1              3             1       both    -2     2.0
# 2              1             1       both     0     NaN
# 3              3             3       both     0     NaN
# 4              2             0  left_only    -2     2.0

# %%
df_discrepancy.head()
# Out:
#   Retail_Product_Color Retail_Product_Level1 Retail_Product_Level1Name  \
# 0               BRANCO                     C                 VESTUARIO
# 1                 ROSA                     C                 VESTUARIO
# 2                  NaN                     H        ELETRO-ELETRONICOS
# 3                JEANS                     C                 VESTUARIO
# 4                JEANS                     C                 VESTUARIO
#
#   Retail_Product_Level2Name Retail_Product_Level3Name  \
# 0                        CR                       CRB
# 1                        CY                       CYA
# 2                        HZ                       HZB
# 3                        CY                       CYA
# 4                        CY                       CYC
#
#   Retail_Product_Level4Name                       Retail_Product_Name  \
# 0                      CRBK  CALCINHA CR SLO ELLA ESTAMPADO CINZA P B
# 1                      CYAE  BERMUDA SARJA CRN SLO INK ABERTURA BARRA
# 2                      HZBO  RELOGIO FEM MONDAINE PRATA KIT COLAR ANA
# 3                      CYAA  CALCA JEANS CF MSA INK USED TANK DIRT LI
# 4                      CYCD  SHORT JEANS PS PRD BARRA DOBRADA E PREGA
#
#   Retail_Product_SKU Retail_Product_Size     Retail_Product_Style  \
# 0         9568860004                   P             KIT CALCINHA
# 1         9384260002                  40       BOTTOM CURTO SARJA
# 2         9735510000                 NaN       KIT FEMININO PRATA
# 3         9579550002                  38              CALÇA JEANS
# 4         9633210004                  52  BOTTOM CURTO JEANS PLUS
#
#    Retail_SOHQTY  Retail_CCQTY     _merge  Diff  Unders
# 0              1             1       both     0       0
# 1              3             1       both    -2       2
# 2              1             1       both     0       0
# 3              3             3       both     0       0
# 4              2             0  left_only    -2       2

# %%
df_discrepancy.groupby('Retail_Product_Level1Name').sum()
# Out:
#                            Retail_SOHQTY  Retail_CCQTY  Diff  Unders
# Retail_Product_Level1Name
# BELEZA                               729           647   -82      84
# ELETRO-ELETRONICOS                   206           193   -13      14
# VESTUARIO                           6376          2891 -3485    3516

# %%
df_discrepancy.groupby('Retail_Product_Level2Name').sum()
# Out:
#                            Retail_SOHQTY  Retail_CCQTY  Diff  Unders
# Retail_Product_Level2Name
# C5                                   291           100  -191     191
# C6                                   698           455  -243     257
# C7                                   166           123   -43      45
# C8                                   315           102  -213     213
# C9                                   148            59   -89      89
# CJ                                   531           399  -132     133
# CM                                   668            30  -638     638
# CN                                   427           369   -58      67
# CP                                   675           157  -518     518
# CR                                   511           461   -50      52
# CY                                  1946           636 -1310    1313
# HB                                    89            75   -14      14
# HJ                                    17            17     0       0
# HZ                                   100           101     1       0
# WA                                   348           297   -51      51
# WB                                   169           159   -10      11
# WK                                    87            87     0       0
# WL                                   125           104   -21      22
